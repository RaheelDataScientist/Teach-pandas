# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("C:\\Users\\DELL\\Downloads\\file (6).csv")
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()

# Null Values means Missing Values
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
data.drop(columns = ['Region       321'], inplace = True)

# %%
data
# Out:
#           Date          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020     Afghanistan       1939      60        252
# 1    4/29/2020         Albania        766      30        455
# 2    4/29/2020         Algeria       3848     444       1702
# 3    4/29/2020         Andorra        743      42        423
# 4    4/29/2020          Angola         27       2          7
# ..         ...             ...        ...     ...        ...
# 316  4/29/2020              US        545       7          0
# 317  4/29/2020  Mainland China         76       3         73
# 318  4/29/2020          Canada         11       0          0
# 319  4/29/2020  Mainland China        185       2        181
# 320  4/29/2020  Mainland China       1268       1       1263
#
# [321 rows x 5 columns]

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # Q:1.Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
# data.groupby('Region').sum().head(20)

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')[['Confirmed', 'Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# # Q:2.Remove all the records where Conference Case is less than 10

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data = data[~data.Confirmed < 10]

# %%
data.head(20)
# Out:
#          Date State               Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN          Afghanistan       1939      60        252
# 1   4/29/2020   NaN              Albania        766      30        455
# 2   4/29/2020   NaN              Algeria       3848     444       1702
# 3   4/29/2020   NaN              Andorra        743      42        423
# 4   4/29/2020   NaN               Angola         27       2          7
# 5   4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN            Argentina       4285     214       1192
# 7   4/29/2020   NaN              Armenia       1932      30        900
# 8   4/29/2020   NaN              Austria      15402     580      12779
# 9   4/29/2020   NaN           Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN              Bahamas         80      11         23
# 11  4/29/2020   NaN              Bahrain       2921       8       1455
# ...

# %% [markdown]
# # Q:3.In which Region maximum number of confired cases were recorded ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q:4.In which Region minimum number of Deaths cases were recorded ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Region
# Laos                        0
# Mongolia                    0
# Mozambique                  0
# Cambodia                    0
# Fiji                        0
# Namibia                     0
# Nepal                       0
# Madagascar                  0
# Macau                       0
# Papua New Guinea            0
# Rwanda                      0
# Saint Kitts and Nevis       0
# Bhutan                      0
# Dominica                    0
# Central African Republic    0
# Saint Lucia                 0
# Holy See                    0
# Sao Tome and Principe       0
# Yemen                       0
# Western Sahara              0
# Name: Deaths, dtype: int64

# %% [markdown]
# # Q:5.How many Confirmed, Deaths & Recovered cases were reported from india till 29 April 2020 ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == 'Yemen']
# Out:
#           Date State Region  Confirmed  Deaths  Recovered
# 178  4/29/2020   NaN  Yemen          6       0          1

# %%
data[data.Region == 'US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# # Q.:6-A.Sort the entire data wrt No.of Confirmed cases in ascending order.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values( by = ['Confirmed'], ascending = True).head(50)
# Out:
#           Date                             State  \
# 285  4/29/2020                         Recovered
# 284  4/29/2020                         Recovered
# 203  4/29/2020      Diamond Princess cruise ship
# 305  4/29/2020                             Tibet
# 289  4/29/2020         Saint Pierre and Miquelon
# 184  4/29/2020                          Anguilla
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba
# 272  4/29/2020             Northwest Territories
# 288  4/29/2020                  Saint Barthelemy
# 178  4/29/2020                               NaN
# 194  4/29/2020            British Virgin Islands
# 177  4/29/2020                               NaN
# 18   4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 140  4/29/2020                               NaN
# 105  4/29/2020                               NaN
# 98   4/29/2020                               NaN
# 156  4/29/2020                               NaN
# ...
